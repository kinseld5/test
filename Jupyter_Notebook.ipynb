# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **DAVID KINSELLA**
#
# Data Scientist

# %% [markdown]
# *I am interested in data science because I understand the power of data and I want to have the ability to identify patterns and insights from the data available. Data is King!*

# %% [markdown]
# ### Plots some positive numbers (x) against some negative numbers (y)

# %%
x = [1, 3, 5, 7]
y = [-1, -3, -5, -7]
import matplotlib.pyplot as plt
plt.plot(x,y)
plt.show()

# %% [markdown]
# ***
# ~strikethough~
#
# <u>hyperlink<u>
